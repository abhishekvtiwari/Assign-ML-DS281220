# %%
import pandas as pd
import seaborn as sns
data = pd.read_csv(r"E:/GITHUB/data-science-complete-tutorial/Data/house_rental_data.csv.txt",index_col=0)
data.head()
# Out:
#        Sqft  Floor  TotalFloor  Bedroom  Living.Room  Bathroom  Price
# 1  1177.698      2           7        2            2         2  62000
# 2  2134.800      5           7        4            2         2  78000
# 3  1138.560      5           7        2            2         1  58000
# 4  1458.780      2           7        3            2         2  45000
# 5   967.776     11          14        3            2         2  45000

# %%
corr = data.corr()
sns.heatmap(corr, annot = True)
# Out:
# <AxesSubplot:>

# %%
cols = data.columns
for i in cols[:-1]:
    sns.jointplot(x = i, y = "Price",data = data, kind = "reg")

# %%
sns.pairplot(data=data,)

# %%
data.hist(bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'Sqft'}>,
#         <AxesSubplot:title={'center':'Floor'}>,
#         <AxesSubplot:title={'center':'TotalFloor'}>],
#        [<AxesSubplot:title={'center':'Bedroom'}>,
#         <AxesSubplot:title={'center':'Living.Room'}>,
#         <AxesSubplot:title={'center':'Bathroom'}>],
#        [<AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
data['Price'].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Bathroom'].plot.hist(bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
data['Sqft'].plot.hist(bins = 50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
X = data.iloc[:,:-1].values
y = data["Price"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.25, random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
print(model.score(X_test, y_test))
# Out:
# 0.6523894789774944

# %%
from sklearn.ensemble import GradientBoostingRegressor
grad = GradientBoostingRegressor()
grad.fit(X_train, y_train)
print(grad.score(X_test, y_test))
# Out:
# 0.7670372027133274
